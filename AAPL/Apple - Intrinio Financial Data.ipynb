# %%
import pandas as pd
from pandas.io.json import json_normalize
import time

# %%
import pandas as pd
from __future__ import print_function
import time
import intrinio_sdk
from intrinio_sdk.rest import ApiException
from pprint import pprint

intrinio_sdk.ApiClient().configuration.api_key['api_key'] = 'OjJjNjUwYjVlNjA1YTYzODIzODVlYzZkYjVjMWEyZjli'
#Sandbox API key = OjJjNjUwYjVlNjA1YTYzODIzODVlYzZkYjVjMWEyZjli
#production API key = OjI0MjQ1ZjNhY2I0Zjk5MDkwZWNmNTFmYzM1YWQxNDZl

# %%
security_api = intrinio_sdk.SecurityApi()
identifier = 'AAPL' # str | A Security identifier (Ticker, FIGI, ISIN, CUSIP, Intrinio ID)
start_date = '2008-01-02' # date | Return intraday prices starting at the specified date (optional)
end_date = '' # date | Return intraday prices stopping at the specified date (optional)
page_size = 1200
try:
    api_response = security_api.get_security_stock_prices(identifier, page_size=page_size, start_date=start_date, end_date=end_date)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling SecurityApi->get_security_intraday_prices: %s\n" % e)

# Note: For a Pandas DataFrame, import Pandas and use pd.DataFrame(api_response.intraday_prices_dict)
# Out:
# {'next_page': 'MjAxNC0xMC0yOXwxMDE5MDU0ODE0MA==',
#  'security': {'code': 'EQS',
#               'company_id': 'com_NX6GzO',
#               'composite_figi': 'BBG000B9XRY4',
#               'composite_ticker': 'AAPL:US',
#               'currency': 'USD',
#               'figi': 'BBG000B9Y5X2',
#               'id': 'sec_agjrgj',
#               'name': 'Apple Inc',
#               'share_class_figi': 'BBG001S5N8V8',
#               'ticker': 'AAPL'},
#  'stock_prices': [{'adj_close': 197.0,
#                    'adj_high': 198.067,
#                    'adj_low': 194.04,
#                    'adj_open': 196.31,
#                    'adj_volume': 35824787.0,
#                    'close': 197.0,
#                    'date': datetime.date(2019, 8, 6),
#                    'frequency': 'daily',
#                    'high': 198.067,
#                    'intraperiod': False,
#                    'low': 194.04,
#                    'open': 196.31,
# ...

# %%
df_prices = pd.DataFrame(api_response.stock_prices_dict)
df_prices.tail()
# Out:
#        adj_close    adj_high    adj_low    adj_open  adj_volume   close  \
# 1195  100.029654  100.849418  99.219101  100.729677  41574365.0  108.60
# 1196  100.766521  101.595496  99.486215   99.679642  52282550.0  109.40
# 1197   99.477004   99.513847  98.749348   99.486215  44639285.0  108.00
# 1198   98.537499   98.878300  97.542729   98.518156  40654793.0  106.98
# 1199   98.869089   98.896722  97.966427   98.233542  52687879.0  107.34
#
#             date frequency    high  intraperiod     low     open      volume
# 1195  2014-11-04     daily  109.49        False  107.72  109.360  41574365.0
# 1196  2014-11-03     daily  110.30        False  108.01  108.220  52282550.0
# 1197  2014-10-31     daily  108.04        False  107.21  108.010  44639285.0
# 1198  2014-10-30     daily  107.35        False  105.90  106.959  40654793.0
# 1199  2014-10-29     daily  107.37        False  106.36  106.650  52687879.0

# %%
df_prices.to_csv('apple_price.csv')

# %%
tags = ['marketcap','pricetobook','pricetoearnings','nopat'#net opertaing profit after tax
        'dividendyield','freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare', 'bookvaluepershare',
       'capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa'
       'revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','earningsyield','one_yr_monthly_beta',
       'netincome','netcashfromoperatingactivities','netcashfrominvestingactivities','netcashfromfinancingactivities','longterminvestments','one_yr_monthly_beta']

# %%
#tags = ['marketcap','pricetobook']

# %%
#df_fundamentals=[]
#for tag in tags:
 #   try:
  #      api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
   #     df_fundamentals.append(api_response.historical_data_dict)
        
    #except ApiException as e:
     #   time.sleep(60)
      #  print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

# %%
#df_fundamentals.head()

# %%
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'marketcap' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = 'daily' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2008-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
    
# Note: For a Pandas DataFrame, import Pandas and use pd.DataFrame(api_response.property_name_dict)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 8, 6),
#                       'value': 906471860000.0},
#                      {'date': datetime.date(2019, 8, 5),
#                       'value': 889630809200.0},
#                      {'date': datetime.date(2019, 8, 2),
#                       'value': 938773547600.0},
#                      {'date': datetime.date(2019, 8, 1),
#                       'value': 959065633400.0},
#                      {'date': datetime.date(2019, 7, 31),
#                       'value': 980277995200.0},
#                      {'date': datetime.date(2019, 7, 30),
#                       'value': 960676116400.0},
#                      {'date': datetime.date(2019, 7, 29),
#                       'value': 964817358400.0},
# ...

# %%
df_marketcap = pd.DataFrame(api_response.historical_data_dict)
df_marketcap.tail()
# Out:
#             date         value
# 1195  2014-11-04  6.124479e+11
# 1196  2014-11-03  6.169594e+11
# 1197  2014-10-31  6.090642e+11
# 1198  2014-10-30  6.033119e+11
# 1199  2014-10-29  6.053421e+11

# %%
df_marketcap.rename(columns = {'value': tag })
# Out:
#             date     marketcap
# 0     2019-08-06  9.064719e+11
# 1     2019-08-05  8.896308e+11
# 2     2019-08-02  9.387735e+11
# 3     2019-08-01  9.590656e+11
# 4     2019-07-31  9.802780e+11
# 5     2019-07-30  9.606761e+11
# 6     2019-07-29  9.648174e+11
# 7     2019-07-26  9.558907e+11
# 8     2019-07-25  9.525777e+11
# 9     2019-07-24  9.601700e+11
# 10    2019-07-23  9.609522e+11
# 11    2019-07-22  9.534980e+11
# 12    2019-07-19  9.321936e+11
# 13    2019-07-18  9.463198e+11
# 14    2019-07-17  9.356906e+11
# 15    2019-07-16  9.409822e+11
# 16    2019-07-15  9.442492e+11
# 17    2019-07-12  9.354606e+11
# 18    2019-07-11  9.283284e+11
# 19    2019-07-10  9.351385e+11
# 20    2019-07-09  9.259817e+11
# 21    2019-07-08  9.203680e+11
# 22    2019-07-05  9.397398e+11
# 23    2019-07-03  9.405681e+11
# 24    2019-07-02  9.328378e+11
# 25    2019-07-01  9.274081e+11
# 26    2019-06-28  9.303519e+11
# 27    2019-06-27  9.389070e+11
# 28    2019-06-26  9.391891e+11
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'pricetobook' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = 'daily' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
    
# Note: For a Pandas DataFrame, import Pandas and use pd.DataFrame(api_response.property_name_dict)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 8, 6), 'value': 9.3978},
#                      {'date': datetime.date(2019, 8, 5), 'value': 9.2232},
#                      {'date': datetime.date(2019, 8, 2), 'value': 9.7327},
#                      {'date': datetime.date(2019, 8, 1), 'value': 9.943},
#                      {'date': datetime.date(2019, 7, 31), 'value': 10.163},
#                      {'date': datetime.date(2019, 7, 30), 'value': 9.9597},
#                      {'date': datetime.date(2019, 7, 29), 'value': 10.0027},
#                      {'date': datetime.date(2019, 7, 26), 'value': 9.9101},
#                      {'date': datetime.date(2019, 7, 25), 'value': 9.8758},
#                      {'date': datetime.date(2019, 7, 24), 'value': 9.9545},
# ...

# %%
df_pb = pd.DataFrame(api_response.historical_data_dict)
df_pb.tail()
# Out:
#             date   value
# 1151  2015-01-08  4.9365
# 1152  2015-01-07  4.7538
# 1153  2015-01-06  4.6881
# 1154  2015-01-05  4.6877
# 1155  2015-01-02  4.8235

# %%
df_pb.rename(columns = {'value': tag })
# Out:
#             date  pricetobook
# 0     2019-08-06       9.3978
# 1     2019-08-05       9.2232
# 2     2019-08-02       9.7327
# 3     2019-08-01       9.9430
# 4     2019-07-31      10.1630
# 5     2019-07-30       9.9597
# 6     2019-07-29      10.0027
# 7     2019-07-26       9.9101
# 8     2019-07-25       9.8758
# 9     2019-07-24       9.9545
# 10    2019-07-23       9.9626
# 11    2019-07-22       9.8853
# 12    2019-07-19       9.6644
# 13    2019-07-18       9.8109
# 14    2019-07-17       9.7007
# 15    2019-07-16       9.7556
# 16    2019-07-15       9.7894
# 17    2019-07-12       9.6983
# 18    2019-07-11       9.6244
# 19    2019-07-10       9.6950
# 20    2019-07-09       9.6000
# 21    2019-07-08       9.5418
# 22    2019-07-05       9.7427
# 23    2019-07-03       9.7513
# 24    2019-07-02       9.6711
# 25    2019-07-01       9.6148
# 26    2019-06-28       8.7885
# 27    2019-06-27       8.8693
# 28    2019-06-26       8.8720
# 29    2019-06-25       8.6842
# ...

# %%
df=pd.merge(df_marketcap,df_pb, how='outer', on='date')

# %%
df.columns = ['date', 'marketcap', 'pricetobook']
df.head()
# Out:
#          date     marketcap  pricetobook
# 0  2019-08-06  9.064719e+11       9.3978
# 1  2019-08-05  8.896308e+11       9.2232
# 2  2019-08-02  9.387735e+11       9.7327
# 3  2019-08-01  9.590656e+11       9.9430
# 4  2019-07-31  9.802780e+11      10.1630

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'pricetoearnings' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = 'daily' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)


# Note: For a Pandas DataFrame, import Pandas and use pd.DataFrame(api_response.property_name_dict)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 8, 6), 'value': 16.2756},
#                      {'date': datetime.date(2019, 8, 5), 'value': 15.9733},
#                      {'date': datetime.date(2019, 8, 2), 'value': 16.8556},
#                      {'date': datetime.date(2019, 8, 1), 'value': 17.22},
#                      {'date': datetime.date(2019, 7, 31), 'value': 17.6008},
#                      {'date': datetime.date(2019, 7, 30), 'value': 17.2489},
#                      {'date': datetime.date(2019, 7, 29), 'value': 17.3232},
#                      {'date': datetime.date(2019, 7, 26), 'value': 17.163},
#                      {'date': datetime.date(2019, 7, 25), 'value': 17.1035},
#                      {'date': datetime.date(2019, 7, 24), 'value': 17.2398},
# ...

# %%
df_pe = pd.DataFrame(api_response.historical_data_dict)
df_pe.tail()
# Out:
#             date    value
# 1151  2015-01-08  13.6928
# 1152  2015-01-07  13.1861
# 1153  2015-01-06  13.0038
# 1154  2015-01-05  13.0025
# 1155  2015-01-02  13.3795

# %%
df_pe.rename(columns = {'value': tag })
# Out:
#             date  pricetoearnings
# 0     2019-08-06          16.2756
# 1     2019-08-05          15.9733
# 2     2019-08-02          16.8556
# 3     2019-08-01          17.2200
# 4     2019-07-31          17.6008
# 5     2019-07-30          17.2489
# 6     2019-07-29          17.3232
# 7     2019-07-26          17.1630
# 8     2019-07-25          17.1035
# 9     2019-07-24          17.2398
# 10    2019-07-23          17.2538
# 11    2019-07-22          17.1200
# 12    2019-07-19          16.7375
# 13    2019-07-18          16.9911
# 14    2019-07-17          16.8003
# 15    2019-07-16          16.8953
# 16    2019-07-15          16.9539
# 17    2019-07-12          16.7961
# 18    2019-07-11          16.6681
# 19    2019-07-10          16.7903
# 20    2019-07-09          16.6259
# 21    2019-07-08          16.5251
# 22    2019-07-05          16.8730
# 23    2019-07-03          16.8878
# 24    2019-07-02          16.7490
# 25    2019-07-01          16.6516
# ...

# %%
df=pd.merge(df,df_pe, on='date',how='left')
df.columns = ['date', 'marketcap', 'pricetobook','pricetoearnings']
df.head()
# Out:
#          date     marketcap  pricetobook  pricetoearnings
# 0  2019-08-06  9.064719e+11       9.3978          16.2756
# 1  2019-08-05  8.896308e+11       9.2232          15.9733
# 2  2019-08-02  9.387735e+11       9.7327          16.8556
# 3  2019-08-01  9.590656e+11       9.9430          17.2200
# 4  2019-07-31  9.802780e+11      10.1630          17.6008

# %%
#import time
#time.sleep(1.3)

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'dividendyield' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 8, 6), 'value': 0.018731},
#                      {'date': datetime.date(2019, 8, 5), 'value': 0.019086},
#                      {'date': datetime.date(2019, 8, 2), 'value': 0.018086},
#                      {'date': datetime.date(2019, 8, 1), 'value': 0.017704},
#                      {'date': datetime.date(2019, 7, 31), 'value': 0.017321},
#                      {'date': datetime.date(2019, 7, 30), 'value': 0.017674},
#                      {'date': datetime.date(2019, 7, 29), 'value': 0.017598},
#                      {'date': datetime.date(2019, 7, 26), 'value': 0.017763},
#                      {'date': datetime.date(2019, 7, 25), 'value': 0.017824},
#                      {'date': datetime.date(2019, 7, 24), 'value': 0.017683},
# ...

# %%
df_dividendyield = pd.DataFrame(api_response.historical_data_dict)
df_dividendyield.head()
# Out:
#          date     value
# 0  2019-08-06  0.018731
# 1  2019-08-05  0.019086
# 2  2019-08-02  0.018086
# 3  2019-08-01  0.017704
# 4  2019-07-31  0.017321

# %%
df=pd.merge(df,df_dividendyield, on='date',how='outer')
df.columns = ['date', 'marketcap', 'pricetobook','pricetoearnings','dividendyield']
df.head()
# Out:
#          date     marketcap  pricetobook  pricetoearnings  dividendyield
# 0  2019-08-06  9.064719e+11       9.3978          16.2756       0.018731
# 1  2019-08-05  8.896308e+11       9.2232          15.9733       0.019086
# 2  2019-08-02  9.387735e+11       9.7327          16.8556       0.018086
# 3  2019-08-01  9.590656e+11       9.9430          17.2200       0.017704
# 4  2019-07-31  9.802780e+11      10.1630          17.6008       0.017321

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'earningsyield' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 8, 6), 'value': 0.061442},
#                      {'date': datetime.date(2019, 8, 5), 'value': 0.062605},
#                      {'date': datetime.date(2019, 8, 2), 'value': 0.059327},
#                      {'date': datetime.date(2019, 8, 1), 'value': 0.058072},
#                      {'date': datetime.date(2019, 7, 31), 'value': 0.056816},
#                      {'date': datetime.date(2019, 7, 30), 'value': 0.057975},
#                      {'date': datetime.date(2019, 7, 29), 'value': 0.057726},
#                      {'date': datetime.date(2019, 7, 26), 'value': 0.058265},
#                      {'date': datetime.date(2019, 7, 25), 'value': 0.058468},
#                      {'date': datetime.date(2019, 7, 24), 'value': 0.058005},
# ...

# %%
df_earningsyield= pd.DataFrame(api_response.historical_data_dict)
df_earningsyield.head()
# Out:
#          date     value
# 0  2019-08-06  0.061442
# 1  2019-08-05  0.062605
# 2  2019-08-02  0.059327
# 3  2019-08-01  0.058072
# 4  2019-07-31  0.056816

# %%
df=pd.merge(df,df_earningsyield, on='date',how='outer')
df.columns = ['date', 'marketcap', 'pricetobook','pricetoearnings','dividendyield','earningsyield']
df.head()
# Out:
#          date     marketcap  pricetobook  pricetoearnings  dividendyield  \
# 0  2019-08-06  9.064719e+11       9.3978          16.2756       0.018731
# 1  2019-08-05  8.896308e+11       9.2232          15.9733       0.019086
# 2  2019-08-02  9.387735e+11       9.7327          16.8556       0.018086
# 3  2019-08-01  9.590656e+11       9.9430          17.2200       0.017704
# 4  2019-07-31  9.802780e+11      10.1630          17.6008       0.017321
#
#    earningsyield
# 0       0.061442
# 1       0.062605
# 2       0.059327
# 3       0.058072
# 4       0.056816

# %%
df.describe()
# Out:
#           marketcap  pricetobook  pricetoearnings  dividendyield  \
# count  1.200000e+03  1156.000000      1156.000000    1156.000000
# mean   7.419423e+11     6.070053        14.617308       0.019753
# std    1.570669e+11     1.649891         2.665311       0.004760
# min    4.763883e+11     3.651700         9.150900       0.011857
# 25%    6.119603e+11     4.827800        12.347325       0.015572
# 50%    7.191062e+11     5.577200        14.961200       0.019411
# 75%    8.738135e+11     6.891900        16.791100       0.023792
# max    1.146985e+12    10.704800        19.815700       0.030822
#
#        earningsyield
# count    1156.000000
# mean        0.070979
# std         0.014339
# min         0.050465
# 25%         0.059555
# 50%         0.066839
# 75%         0.080989
# max         0.109279

# %%
df.tail()
# Out:
#             date     marketcap  pricetobook  pricetoearnings  dividendyield  \
# 1195  2014-11-04  6.124479e+11          NaN              NaN            NaN
# 1196  2014-11-03  6.169594e+11          NaN              NaN            NaN
# 1197  2014-10-31  6.090642e+11          NaN              NaN            NaN
# 1198  2014-10-30  6.033119e+11          NaN              NaN            NaN
# 1199  2014-10-29  6.053421e+11          NaN              NaN            NaN
#
#       earningsyield
# 1195            NaN
# 1196            NaN
# 1197            NaN
# 1198            NaN
# 1199            NaN

# %%
df['date']=pd.to_datetime(df.date,format='%Y-%m-%d')
df.index =df['date']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1200 entries, 2019-08-06 to 2014-10-29
# Data columns (total 6 columns):
# date               1200 non-null datetime64[ns]
# marketcap          1200 non-null float64
# pricetobook        1156 non-null float64
# pricetoearnings    1156 non-null float64
# dividendyield      1156 non-null float64
# earningsyield      1156 non-null float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 65.6 KB

# %% [markdown]
# ### Quarterly Fundmental Data Collection

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'nopat' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 55547452228.4},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 57890268848.8},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 57893760723.2},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 54127871134.5},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 51473536793.2},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 48502158308.3},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 46280075270.3},
# ...

# %%
df_nopat = pd.DataFrame(api_response.historical_data_dict)
df_nopat.head()
# Out:
#          date         value
# 0  2019-03-30  5.554745e+10
# 1  2018-12-29  5.789027e+10
# 2  2018-09-29  5.789376e+10
# 3  2018-06-30  5.412787e+10
# 4  2018-03-31  5.147354e+10

# %%
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'freecashflow' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 43960452228.4},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 47805268848.8},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 54195760723.2},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 47569871134.5},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 45744536793.2},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 44849158308.3},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 43144075270.3},
# ...

# %%
df_freecashflow = pd.DataFrame(api_response.historical_data_dict)
df_freecashflow.head()
# Out:
#          date         value
# 0  2019-03-30  4.396045e+10
# 1  2018-12-29  4.780527e+10
# 2  2018-09-29  5.419576e+10
# 3  2018-06-30  4.756987e+10
# 4  2018-03-31  4.574454e+10

# %%
df1=pd.merge(df_nopat,df_freecashflow, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow']
df1.head()
# Out:
#          date         nopat  freecashflow
# 0  2019-03-30  5.554745e+10  4.396045e+10
# 1  2018-12-29  5.789027e+10  4.780527e+10
# 2  2018-09-29  5.789376e+10  5.419576e+10
# 3  2018-06-30  5.412787e+10  4.756987e+10
# 4  2018-03-31  5.147354e+10  4.574454e+10

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'roe' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.491282},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.460543},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.493636},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.453726},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.40863},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.370705},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.368675},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.360287},
#                      {'date': datetime.date(2017, 4, 1), 'value': 0.345734},
#                      {'date': datetime.date(2016, 12, 31), 'value': 0.346946},
# ...

# %%
df_roe = pd.DataFrame(api_response.historical_data_dict)
df_roe.head()
# Out:
#          date     value
# 0  2019-03-30  0.491282
# 1  2018-12-29  0.460543
# 2  2018-09-29  0.493636
# 3  2018-06-30  0.453726
# 4  2018-03-31  0.408630

# %%
df1=pd.merge(df1,df_roe, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe']
df1.head()
# Out:
#          date         nopat  freecashflow       roe
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'ebitdagrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.006515},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.058266},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.128761},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.116435},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.094988},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.074626},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.032959},
#                      {'date': datetime.date(2017, 7, 1), 'value': -0.03639},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.09977},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.151718},
# ...

# %%
df_ebitdagrowth = pd.DataFrame(api_response.historical_data_dict)
df_ebitdagrowth.head()
# Out:
#          date     value
# 0  2019-03-30  0.006515
# 1  2018-12-29  0.058266
# 2  2018-09-29  0.128761
# 3  2018-06-30  0.116435
# 4  2018-03-31  0.094988

# %%
df1=pd.merge(df1,df_ebitdagrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'ebitdamargin' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.306619},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.310888},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.315541},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.317431},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.318268},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.321328},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.323887},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.324737},
#                      {'date': datetime.date(2017, 4, 1), 'value': 0.326204},
#                      {'date': datetime.date(2016, 12, 31), 'value': 0.327882},
# ...

# %%
df_ebitdamargin = pd.DataFrame(api_response.historical_data_dict)
df_ebitdamargin.head()
# Out:
#          date     value
# 0  2019-03-30  0.306619
# 1  2018-12-29  0.310888
# 2  2018-09-29  0.315541
# 3  2018-06-30  0.317431
# 4  2018-03-31  0.318268

# %%
df1=pd.merge(df1,df_ebitdamargin, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin
# 0      0.306619
# 1      0.310888
# 2      0.315541
# 3      0.317431
# 4      0.318268

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'cashdividendspershare' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 2.92},
#                      {'date': datetime.date(2018, 12, 29), 'value': 2.82},
#                      {'date': datetime.date(2018, 9, 29), 'value': 2.72},
#                      {'date': datetime.date(2018, 6, 30), 'value': 2.62},
#                      {'date': datetime.date(2018, 3, 31), 'value': 2.52},
#                      {'date': datetime.date(2017, 12, 30), 'value': 2.46},
#                      {'date': datetime.date(2017, 9, 30), 'value': 2.4},
#                      {'date': datetime.date(2017, 7, 1), 'value': 2.34},
#                      {'date': datetime.date(2017, 4, 1), 'value': 2.38},
#                      {'date': datetime.date(2016, 12, 31), 'value': 2.32},
# ...

# %%
df_cashdividendspershare = pd.DataFrame(api_response.historical_data_dict)
df_cashdividendspershare.head()
# Out:
#          date  value
# 0  2019-03-30   2.92
# 1  2018-12-29   2.82
# 2  2018-09-29   2.72
# 3  2018-06-30   2.62
# 4  2018-03-31   2.52

# %%
df1=pd.merge(df1,df_cashdividendspershare, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare
# 0      0.306619                   2.92
# 1      0.310888                   2.82
# 2      0.315541                   2.72
# 3      0.317431                   2.62
# 4      0.318268                   2.52

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'bookvaluepershare' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 22.5203},
#                      {'date': datetime.date(2018, 12, 29), 'value': 24.6985},
#                      {'date': datetime.date(2018, 9, 29), 'value': 21.4289},
#                      {'date': datetime.date(2018, 6, 30), 'value': 23.3323},
#                      {'date': datetime.date(2018, 3, 31), 'value': 25.0327},
#                      {'date': datetime.date(2017, 12, 30), 'value': 27.182},
#                      {'date': datetime.date(2017, 9, 30), 'value': 25.5245},
#                      {'date': datetime.date(2017, 7, 1), 'value': 25.3033},
#                      {'date': datetime.date(2017, 4, 1), 'value': 25.4827},
#                      {'date': datetime.date(2016, 12, 31), 'value': 24.848},
# ...

# %%
df_bookvaluepershare = pd.DataFrame(api_response.historical_data_dict)
df_bookvaluepershare.head()
# Out:
#          date    value
# 0  2019-03-30  22.5203
# 1  2018-12-29  24.6985
# 2  2018-09-29  21.4289
# 3  2018-06-30  23.3323
# 4  2018-03-31  25.0327

# %%
df1=pd.merge(df1,df_bookvaluepershare, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare
# 0      0.306619                   2.92            22.5203
# 1      0.310888                   2.82            24.6985
# 2      0.315541                   2.72            21.4289
# 3      0.317431                   2.62            23.3323
# 4      0.318268                   2.52            25.0327

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'capex' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 12026000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 13858000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 13313000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 14137000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 13147000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 11927000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 12451000000.0},
# ...

# %%
df_capex = pd.DataFrame(api_response.historical_data_dict)
df_capex.head()
# Out:
#          date         value
# 0  2019-03-30  1.202600e+10
# 1  2018-12-29  1.385800e+10
# 2  2018-09-29  1.331300e+10
# 3  2018-06-30  1.413700e+10
# 4  2018-03-31  1.314700e+10

# %%
df1=pd.merge(df1,df_capex, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'currentratio' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 1.3154},
#                      {'date': datetime.date(2018, 12, 29), 'value': 1.3006},
#                      {'date': datetime.date(2018, 9, 29), 'value': 1.1329},
#                      {'date': datetime.date(2018, 6, 30), 'value': 1.3073},
#                      {'date': datetime.date(2018, 3, 31), 'value': 1.456},
#                      {'date': datetime.date(2017, 12, 30), 'value': 1.242},
#                      {'date': datetime.date(2017, 9, 30), 'value': 1.2761},
#                      {'date': datetime.date(2017, 7, 1), 'value': 1.3883},
#                      {'date': datetime.date(2017, 4, 1), 'value': 1.3906},
#                      {'date': datetime.date(2016, 12, 31), 'value': 1.2282},
# ...

# %%
df_currentratio = pd.DataFrame(api_response.historical_data_dict)
df_currentratio.head()
# Out:
#          date   value
# 0  2019-03-30  1.3154
# 1  2018-12-29  1.3006
# 2  2018-09-29  1.1329
# 3  2018-06-30  1.3073
# 4  2018-03-31  1.4560

# %%
df1=pd.merge(df1,df_currentratio, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio
# 0        1.3154
# 1        1.3006
# 2        1.1329
# 3        1.3073
# 4        1.4560

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'debttoequity' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 1.0637},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.9732},
#                      {'date': datetime.date(2018, 9, 29), 'value': 1.0688},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.997},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.9603},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.873},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.863},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.8181},
#                      {'date': datetime.date(2017, 4, 1), 'value': 0.7348},
#                      {'date': datetime.date(2016, 12, 31), 'value': 0.6613},
# ...

# %%
df_debttoequity = pd.DataFrame(api_response.historical_data_dict)
df_debttoequity.head()
# Out:
#          date   value
# 0  2019-03-30  1.0637
# 1  2018-12-29  0.9732
# 2  2018-09-29  1.0688
# 3  2018-06-30  0.9970
# 4  2018-03-31  0.9603

# %%
df1=pd.merge(df1,df_debttoequity, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity
# 0        1.3154        1.0637
# 1        1.3006        0.9732
# 2        1.1329        1.0688
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'epsgrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.150434},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.252567},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.29316},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.248869},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.185143},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.141852},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.108303},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.006834},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.047878},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.11789},
# ...

# %%
df_epsgrowth = pd.DataFrame(api_response.historical_data_dict)
df_epsgrowth.head()
# Out:
#          date     value
# 0  2019-03-30  0.150434
# 1  2018-12-29  0.252567
# 2  2018-09-29  0.293160
# 3  2018-06-30  0.248869
# 4  2018-03-31  0.185143

# %%
df1=pd.merge(df1,df_epsgrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth
# 0        1.3154        1.0637   0.150434
# 1        1.3006        0.9732   0.252567
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'investedcapitalgrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.626054},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.448262},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.192926},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.316018},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.236374},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.139689},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.140603},
#                      {'date': datetime.date(2017, 7, 1), 'value': -0.035322},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.072481},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.066996},
# ...

# %%
df_investedcapitalgrowth = pd.DataFrame(api_response.historical_data_dict)
df_investedcapitalgrowth.head()
# Out:
#          date     value
# 0  2019-03-30  0.626054
# 1  2018-12-29  0.448262
# 2  2018-09-29  0.192926
# 3  2018-06-30  0.316018
# 4  2018-03-31  0.236374

# %%
df1=pd.merge(df1,df_investedcapitalgrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth
# 0        1.3154        1.0637   0.150434               0.626054
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'fcffgrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': -0.039001},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.065912},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.256158},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.043604},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.000243},
#                      {'date': datetime.date(2017, 12, 30), 'value': -0.015359},
#                      {'date': datetime.date(2017, 9, 30), 'value': -0.041339},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.03417},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.11345},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.226603},
# ...

# %%
df_fcffgrowth = pd.DataFrame(api_response.historical_data_dict)
df_fcffgrowth.head()
# Out:
#          date     value
# 0  2019-03-30 -0.039001
# 1  2018-12-29  0.065912
# 2  2018-09-29  0.256158
# 3  2018-06-30  0.043604
# 4  2018-03-31  0.000243

# %%
df1=pd.merge(df1,df_fcffgrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'finleverage' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': -1.1093},
#                      {'date': datetime.date(2018, 12, 29), 'value': -1.1353},
#                      {'date': datetime.date(2018, 9, 29), 'value': -1.1436},
#                      {'date': datetime.date(2018, 6, 30), 'value': -1.1413},
#                      {'date': datetime.date(2018, 3, 31), 'value': -1.1638},
#                      {'date': datetime.date(2017, 12, 30), 'value': -1.1785},
#                      {'date': datetime.date(2017, 9, 30), 'value': -1.1581},
#                      {'date': datetime.date(2017, 7, 1), 'value': -1.1575},
#                      {'date': datetime.date(2017, 4, 1), 'value': -1.177},
#                      {'date': datetime.date(2016, 12, 31), 'value': -1.1944},
# ...

# %%
df_finleverage = pd.DataFrame(api_response.historical_data_dict)
df_finleverage.head()
# Out:
#          date   value
# 0  2019-03-30 -1.1093
# 1  2018-12-29 -1.1353
# 2  2018-09-29 -1.1436
# 3  2018-06-30 -1.1413
# 4  2018-03-31 -1.1638

# %%
df1=pd.merge(df1,df_finleverage, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'netincomegrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.072246},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.176269},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.231226},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.202975},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.16593},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.117389},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.05831},
#                      {'date': datetime.date(2017, 7, 1), 'value': -0.023976},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.097636},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.158456},
# ...

# %%
df_netincomegrowth = pd.DataFrame(api_response.historical_data_dict)
df_netincomegrowth.head()
# Out:
#          date     value
# 0  2019-03-30  0.072246
# 1  2018-12-29  0.176269
# 2  2018-09-29  0.231226
# 3  2018-06-30  0.202975
# 4  2018-03-31  0.165930

# %%
df1=pd.merge(df1,df_netincomegrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(40)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'roa' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

# %%
df_roa = pd.DataFrame(api_response.historical_data_dict)
df_roa.head()
# Out:
#          date     value
# 0  2019-03-30  0.161156
# 1  2018-12-29  0.152287
# 2  2018-09-29  0.160668
# 3  2018-06-30  0.161643
# 4  2018-03-31  0.151896

# %%
df1=pd.merge(df1,df_roa, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(50)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'revenuegrowth' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 0.044754},
#                      {'date': datetime.date(2018, 12, 29), 'value': 0.093805},
#                      {'date': datetime.date(2018, 9, 29), 'value': 0.15862},
#                      {'date': datetime.date(2018, 6, 30), 'value': 0.14213},
#                      {'date': datetime.date(2018, 3, 31), 'value': 0.122291},
#                      {'date': datetime.date(2017, 12, 30), 'value': 0.096544},
#                      {'date': datetime.date(2017, 9, 30), 'value': 0.063045},
#                      {'date': datetime.date(2017, 7, 1), 'value': 0.014613},
#                      {'date': datetime.date(2017, 4, 1), 'value': -0.031107},
#                      {'date': datetime.date(2016, 12, 31), 'value': -0.071791},
# ...

# %%
df_revenuegrowth = pd.DataFrame(api_response.historical_data_dict)
df_revenuegrowth.head()
# Out:
#          date     value
# 0  2019-03-30  0.044754
# 1  2018-12-29  0.093805
# 2  2018-09-29  0.158620
# 3  2018-06-30  0.142130
# 4  2018-03-31  0.122291

# %%
df1=pd.merge(df1,df_revenuegrowth, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'basiceps' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30), 'value': 12.03},
#                      {'date': datetime.date(2018, 12, 29), 'value': 12.31},
#                      {'date': datetime.date(2018, 9, 29), 'value': 12.01},
#                      {'date': datetime.date(2018, 6, 30), 'value': 11.13},
#                      {'date': datetime.date(2018, 3, 31), 'value': 10.45},
#                      {'date': datetime.date(2017, 12, 30), 'value': 9.81},
#                      {'date': datetime.date(2017, 9, 30), 'value': 9.27},
#                      {'date': datetime.date(2017, 7, 1), 'value': 8.88},
#                      {'date': datetime.date(2017, 4, 1), 'value': 8.75},
#                      {'date': datetime.date(2016, 12, 31), 'value': 8.53},
# ...

# %%
df_basiceps = pd.DataFrame(api_response.historical_data_dict)
df_basiceps.head()
# Out:
#          date  value
# 0  2019-03-30  12.03
# 1  2018-12-29  12.31
# 2  2018-09-29  12.01
# 3  2018-06-30  11.13
# 4  2018-03-31  10.45

# %%
df1=pd.merge(df1,df_basiceps, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'operatingrevenue' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 258490000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 261612000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 265595000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 255274000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 247417000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 239176000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 229234000000.0},
# ...

# %%
df_operatingrevenue = pd.DataFrame(api_response.historical_data_dict)
df_operatingrevenue.head()
# Out:
#          date         value
# 0  2019-03-30  2.584900e+11
# 1  2018-12-29  2.616120e+11
# 2  2018-09-29  2.655950e+11
# 3  2018-06-30  2.552740e+11
# 4  2018-03-31  2.474170e+11

# %%
df1=pd.merge(df1,df_operatingrevenue, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio  debttoequity  epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(30)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'ebitda' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

# %%
df_ebitda = pd.DataFrame(api_response.historical_data_dict)
df_ebitda.head()
# Out:
#          date         value
# 0  2019-03-30  7.925800e+10
# 1  2018-12-29  8.133200e+10
# 2  2018-09-29  8.380600e+10
# 3  2018-06-30  8.103200e+10
# 4  2018-03-31  7.874500e+10

# %%
df1=pd.merge(df1,df_ebitda, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio      ...       epsgrowth  investedcapitalgrowth  fcffgrowth  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'totalassets' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 341998000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 373719000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 365725000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 349197000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 367502000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 406794000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 375319000000.0},
# ...

# %%
df_totalassets= pd.DataFrame(api_response.historical_data_dict)
df_totalassets.head()
# Out:
#          date         value
# 0  2019-03-30  3.419980e+11
# 1  2018-12-29  3.737190e+11
# 2  2018-09-29  3.657250e+11
# 3  2018-06-30  3.491970e+11
# 4  2018-03-31  3.675020e+11

# %%
df1=pd.merge(df1,df_totalassets, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio      ...       investedcapitalgrowth  fcffgrowth  finleverage  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'totalliabilities' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 236138000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 255827000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 258578000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 234248000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 240624000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 266595000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 241272000000.0},
# ...

# %%
df_totalliabilities= pd.DataFrame(api_response.historical_data_dict)
df_totalliabilities.head()
# Out:
#          date         value
# 0  2019-03-30  2.361380e+11
# 1  2018-12-29  2.558270e+11
# 2  2018-09-29  2.585780e+11
# 3  2018-06-30  2.342480e+11
# 4  2018-03-31  2.406240e+11

# %%
df1=pd.merge(df1,df_totalliabilities, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio        ...         fcffgrowth  finleverage  netincomegrowth  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'debt' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 112606000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 114730000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 114519000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 114600000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 121840000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 122400000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 115680000000.0},
# ...

# %%
df_debt= pd.DataFrame(api_response.historical_data_dict)
df_debt.head()
# Out:
#          date         value
# 0  2019-03-30  1.126060e+11
# 1  2018-12-29  1.147300e+11
# 2  2018-09-29  1.145190e+11
# 3  2018-06-30  1.146000e+11
# 4  2018-03-31  1.218400e+11

# %%
df1=pd.merge(df1,df_debt, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio      ...       finleverage  netincomegrowth       roa  \
# ...

# %%
time.sleep(60)
try:
    api_response = company_api.get_company_historical_data(identifier, 'netincome', frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 57170000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 59431000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 59531000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 56120000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 53318000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 50525000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 48351000000.0},
# ...

# %%
df_netincome= pd.DataFrame(api_response.historical_data_dict)
df_netincome.head()
# Out:
#          date         value
# 0  2019-03-30  5.717000e+10
# 1  2018-12-29  5.943100e+10
# 2  2018-09-29  5.953100e+10
# 3  2018-06-30  5.612000e+10
# 4  2018-03-31  5.331800e+10

# %%
df1=pd.merge(df1,df_netincome, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','netincome']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio      ...       netincomegrowth       roa  revenuegrowth  \
# ...

# %%
try:
    api_response = company_api.get_company_historical_data(identifier, 'netcashfromoperatingactivities', frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

df_netcashfromoperatingactivities= pd.DataFrame(api_response.historical_data_dict)
df_netcashfromoperatingactivities.head()
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 71856000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 75831000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 77434000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 73660000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 67844000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 65284000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 64225000000.0},
# ...

# %%
df1=pd.merge(df1,df_netcashfromoperatingactivities, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','netincome','netcashfromoperatingactivities']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio               ...                     roa  revenuegrowth  \
# ...

# %%
try:
    api_response = company_api.get_company_historical_data(identifier, 'netcashfrominvestingactivities', frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

df_netcashfrominvestingactivities= pd.DataFrame(api_response.historical_data_dict)
df_netcashfrominvestingactivities.head()
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 20138000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 35500000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 16066000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 9125000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 1998000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': -40914000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': -46446000000.0},
# ...

# %%
df1=pd.merge(df1,df_netcashfrominvestingactivities, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','netincome','netcashfromoperatingactivities','netcashfrominvestingactivities']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio               ...                revenuegrowth  basiceps  \
# ...

# %%
time.sleep(50)
try:
    api_response = company_api.get_company_historical_data(identifier, 'netcashfromfinancingactivities', frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

df_netcashfromfinancingactivities= pd.DataFrame(api_response.historical_data_dict)
df_netcashfromfinancingactivities.head()
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': -97236000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': -94051000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': -87876000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': -69385000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': -39940000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': -13250000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': -17974000000.0},
# ...

# %%
df1=pd.merge(df1,df_netcashfromfinancingactivities, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','netincome','netcashfromoperatingactivities','netcashfrominvestingactivities','netcashfromfinancingactivities']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio               ...                basiceps  operatingrevenue  \
# ...

# %%
time.sleep(30)
try:
    api_response = company_api.get_company_historical_data(identifier, 'longterminvestments', frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)

df_longterminvestments= pd.DataFrame(api_response.historical_data_dict)
df_longterminvestments.head()
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 3, 30),
#                       'value': 145319000000.0},
#                      {'date': datetime.date(2018, 12, 29),
#                       'value': 158608000000.0},
#                      {'date': datetime.date(2018, 9, 29),
#                       'value': 170799000000.0},
#                      {'date': datetime.date(2018, 6, 30),
#                       'value': 172773000000.0},
#                      {'date': datetime.date(2018, 3, 31),
#                       'value': 179286000000.0},
#                      {'date': datetime.date(2017, 12, 30),
#                       'value': 207944000000.0},
#                      {'date': datetime.date(2017, 9, 30),
#                       'value': 194714000000.0},
# ...

# %%
df1=pd.merge(df1,df_longterminvestments, on='date',how='outer')
df1.columns = ['date', 'nopat', 'freecashflow','roe','ebitdagrowth','ebitdamargin','cashdividendspershare','bookvaluepershare','capex','currentratio','debttoequity','epsgrowth','investedcapitalgrowth','fcffgrowth','finleverage','netincomegrowth','roa','revenuegrowth','basiceps','operatingrevenue','ebitda','totalassets','totalliabilities','debt','netincome','netcashfromoperatingactivities','netcashfrominvestingactivities','netcashfromfinancingactivities','longterminvestments']
df1.head()
# Out:
#          date         nopat  freecashflow       roe  ebitdagrowth  \
# 0  2019-03-30  5.554745e+10  4.396045e+10  0.491282      0.006515
# 1  2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2  2018-09-29  5.789376e+10  5.419576e+10  0.493636      0.128761
# 3  2018-06-30  5.412787e+10  4.756987e+10  0.453726      0.116435
# 4  2018-03-31  5.147354e+10  4.574454e+10  0.408630      0.094988
#
#    ebitdamargin  cashdividendspershare  bookvaluepershare         capex  \
# 0      0.306619                   2.92            22.5203  1.202600e+10
# 1      0.310888                   2.82            24.6985  1.385800e+10
# 2      0.315541                   2.72            21.4289  1.331300e+10
# 3      0.317431                   2.62            23.3323  1.413700e+10
# 4      0.318268                   2.52            25.0327  1.314700e+10
#
#    currentratio         ...           operatingrevenue        ebitda  \
# ...

# %%
time.sleep(60)
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
tag = 'one_yr_monthly_beta' # str | An Intrinio data tag ID or code (<a href='https://data.intrinio.com/data-tags'>reference</a>)
frequency = '' # str | Return historical data in the given frequency (optional) (default to daily)
type = '' # str | Filter by type, when applicable (optional)
start_date = '2015-01-01' # date | Get historical data on or after this date (optional)
end_date = '' # date | Get historical data on or before this date (optional)
sort_order = 'desc' # str | Sort by date `asc` or `desc` (optional) (default to desc)
next_page = '' # str | Gets the next page of data from a previous API call (optional)
page_size = 1200 # int | The number of results to return (optional) (default to 100)

try:
    api_response = company_api.get_company_historical_data(identifier, tag, frequency=frequency, type=type, start_date=start_date, end_date=end_date, sort_order=sort_order, page_size=page_size, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CompanyApi->get_company_historical_data: %s\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'historical_data': [{'date': datetime.date(2019, 7, 31), 'value': 1.3926},
#                      {'date': datetime.date(2019, 6, 30), 'value': 1.3855},
#                      {'date': datetime.date(2019, 5, 31), 'value': 1.3553},
#                      {'date': datetime.date(2019, 4, 30), 'value': 1.2003},
#                      {'date': datetime.date(2019, 3, 31), 'value': 1.2472},
#                      {'date': datetime.date(2019, 2, 28), 'value': 1.0178},
#                      {'date': datetime.date(2019, 1, 31), 'value': 0.8567},
#                      {'date': datetime.date(2018, 12, 31), 'value': 0.8803},
#                      {'date': datetime.date(2018, 11, 30), 'value': 0.5345},
#                      {'date': datetime.date(2018, 10, 31), 'value': 0.814},
# ...

# %%
df_one_yr_monthly_beta= pd.DataFrame(api_response.historical_data_dict)
df_one_yr_monthly_beta.head()
# Out:
#          date   value
# 0  2019-07-31  1.3926
# 1  2019-06-30  1.3855
# 2  2019-05-31  1.3553
# 3  2019-04-30  1.2003
# 4  2019-03-31  1.2472

# %%
df_one_yr_monthly_beta.rename(columns = {'value': tag })
# Out:
#           date  one_yr_monthly_beta
# 0   2019-07-31               1.3926
# 1   2019-06-30               1.3855
# 2   2019-05-31               1.3553
# 3   2019-04-30               1.2003
# 4   2019-03-31               1.2472
# 5   2019-02-28               1.0178
# 6   2019-01-31               0.8567
# 7   2018-12-31               0.8803
# 8   2018-11-30               0.5345
# 9   2018-10-31               0.8140
# 10  2018-09-30               0.6712
# 11  2018-08-31               0.4864
# 12  2018-07-31               0.0645
# 13  2018-06-30               0.1165
# 14  2018-05-31               0.1066
# 15  2018-04-30              -0.1165
# 16  2018-03-31              -0.1958
# 17  2018-02-28              -0.2959
# 18  2018-01-31               0.1328
# 19  2017-12-31               1.6635
# 20  2017-11-30               0.5030
# 21  2017-10-31               0.8117
# 22  2017-09-30               0.3769
# 23  2017-08-31               0.7229
# 24  2017-07-31               1.2745
# ...

# %%
df_one_yr_monthly_beta.to_csv('AAPL_one_yr_monthly_beta.csv')

# %%
#Upsample Monthly data to daily, (manually finish in excel)
month = pd.read_csv('AAPL_one_yr_monthly_beta.csv')
month['date']= pd.to_datetime(month.date,format='%Y/%m/%d')

month.index =month['date']

month.info()

month.head()
monthly = pd.Series(data=month.value,index=month.date) 

upsampled = monthly.resample('B')
upsampled = upsampled.ffill()
print(upsampled.tail(32))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 55 entries, 2019-07-31 to 2015-01-31
# Data columns (total 3 columns):
# Unnamed: 0    55 non-null int64
# date          55 non-null datetime64[ns]
# value         55 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.7 KB
# date
# 2019-06-18    1.3553
# 2019-06-19    1.3553
# 2019-06-20    1.3553
# 2019-06-21    1.3553
# 2019-06-24    1.3553
# 2019-06-25    1.3553
# 2019-06-26    1.3553
# 2019-06-27    1.3553
# 2019-06-28    1.3553
# 2019-07-01    1.3855
# 2019-07-02    1.3855
# 2019-07-03    1.3855
# 2019-07-04    1.3855
# 2019-07-05    1.3855
# 2019-07-08    1.3855
# 2019-07-09    1.3855
# 2019-07-10    1.3855
# 2019-07-11    1.3855
# 2019-07-12    1.3855
# 2019-07-15    1.3855
# 2019-07-16    1.3855
# 2019-07-17    1.3855
# 2019-07-18    1.3855
# 2019-07-19    1.3855
# 2019-07-22    1.3855
# 2019-07-23    1.3855
# 2019-07-24    1.3855
# 2019-07-25    1.3855
# 2019-07-26    1.3855
# ...

# %%
one_yr_monthly_beta = pd.DataFrame(month)
one_yr_monthly_beta.head()
# Out:
#             Unnamed: 0       date   value
# date
# 2019-07-31           0 2019-07-31  1.3926
# 2019-06-30           1 2019-06-30  1.3855
# 2019-05-31           2 2019-05-31  1.3553
# 2019-04-30           3 2019-04-30  1.2003
# 2019-03-31           4 2019-03-31  1.2472

# %%
beta = upsampled.to_frame('one_yr_monthly_beta') 
beta.head()
beta.to_csv('AAPL_beta.csv')

# %%
#Upsample Quarterly data to daily, (manually do most recent in excel)
#dates = pd.date_range(start='2015-01-31',end='2019-06-30', freq='B')
df1['date']=pd.to_datetime(df1.date,format='%Y-%m-%d')
df1.index =df1['date']

# %%
Quarterly_resampled_data = df1.resample('B')

# %%
Quarterly_resampled_data = Quarterly_resampled_data.ffill()
print(Quarterly_resampled_data.tail(32))
# Out:
#                  date         nopat  freecashflow       roe  ebitdagrowth  \
# date
# 2019-02-14 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-15 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-18 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-19 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-20 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-21 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-22 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-25 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-26 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-27 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-02-28 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# 2019-03-01 2018-12-29  5.789027e+10  4.780527e+10  0.460543      0.058266
# ...

# %%
Quarterly_resampled_data.to_csv('AAPL_Q_resample.csv')

# %%
dates = pd.date_range(start='2015-01-31',end='2019-06-30', freq='B')

# %%
df1.describe()
# Out:
#               nopat  freecashflow        roe  ebitdagrowth  ebitdamargin  \
# count  1.700000e+01  1.700000e+01  17.000000     17.000000     17.000000
# mean   4.986777e+10  4.965713e+10   0.407272      0.075878      0.331586
# std    4.667456e+09  6.763729e+09   0.049071      0.151959      0.016957
# min    4.390674e+10  4.314408e+10   0.345734     -0.151718      0.306619
# 25%    4.628008e+10  4.500451e+10   0.369033     -0.036390      0.318268
# 50%    4.964885e+10  4.574454e+10   0.390638      0.074626      0.326204
# 75%    5.260939e+10  5.419576e+10   0.453726      0.128761      0.348339
# max    5.789376e+10  6.603383e+10   0.493636      0.363721      0.358776
#
#        cashdividendspershare  bookvaluepershare         capex  currentratio  \
# count              17.000000          17.000000  1.700000e+01     17.000000
# mean                2.357059          23.691012  1.246029e+10      1.255182
# std                 0.293359           1.748636  8.388461e+08      0.122072
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 29 columns):
# date                              17 non-null object
# nopat                             17 non-null float64
# freecashflow                      17 non-null float64
# roe                               17 non-null float64
# ebitdagrowth                      17 non-null float64
# ebitdamargin                      17 non-null float64
# cashdividendspershare             17 non-null float64
# bookvaluepershare                 17 non-null float64
# capex                             17 non-null float64
# currentratio                      17 non-null float64
# debttoequity                      17 non-null float64
# epsgrowth                         17 non-null float64
# investedcapitalgrowth             17 non-null float64
# fcffgrowth                        17 non-null float64
# finleverage                       17 non-null float64
# ...

# %%
df.to_csv('AAPL_daily_Fund.csv')

# %%
df1.to_csv('AAPL_QTR_Fund.csv')
